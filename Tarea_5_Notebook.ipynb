# %% [markdown]
# # Tarea 5
# ### En este notebook se realizarán las comprobaciones correspondientes a la tarea 5, todo el codigo y los resultados hayados servirá para la realización del informe. La interpretación de los resultados y las explicaciones de la implementación de las funciones estarán en el informe de prácticas.
# ### Autor: Victor Brown Sogorb

# %% [markdown]
# En la Tarea 5 se deben analizar las métricas y matriz de confusión de todas las combinaciones posibles entre caracteres. Esta tarea se realizará sobre el perceptron de sklearn.
#
# Para esa tarea se ha implementado la función analisis_binario() que se encuentra en el archivo Tarea_5.py. Para más información sobre su funcionamiento revisar el informe de prácticas o los comentarios asociados a su implementación.
#
# Las métricas que vamos a observar son las ya mencionadas en la Tarea_4:
#
# -Precision
#
# -Sensibilidad
#
# -Exactitud

# %% [markdown]
# Pasos previos comentados en anteriores tareas:

# %%
from Funciones.Funciones_prop import carga_data_MNIST  #Importamos dicha función
from Funciones.Tarea_1 import crea_diccionario 
from Funciones.Tarea_2 import getdataset

#Cargamos los datos en las variables images y labels
input_path = 'Data'
file_images = 'emnist-balanced-images-idx3-ubyte.gz'
file_labels = 'emnist-balanced-labels-idx1-ubyte.gz'

[images, labels] = carga_data_MNIST(input_path, file_images, file_labels)


#Creamos el diccionario caracteres
archivo_claves = "Data\\claves_ASCII.txt"
caracteres = crea_diccionario(archivo_claves)

#Obtenemso Ximage e yimage
Ximage, yimage= getdataset(images,labels, caracteres, 16)
# Out:
# ***********************************
# Numero mágico para el archivo de imágenes:
# 2051
# Numero de imágenes:
# 112800
# Numero de filas (imágenes):
# 28
# Numero de columnas (imágenes):
# 28
# ***********************************
# Numero mágico para el archivo de etiquetas:
# 2049
# Numero de etiquetas:
# 112800
# ***********************************

# %% [markdown]
# La función analisis_binario() toma como argumentos Ximage, yimage y el diccionario de caracteres y devuelve las métricas y matriz de confusión de todos los pares.
#
# En el informe de prácticas solo se comentarán aquellos resultados que tengan alguna relevancia (e.j precisión baja)

# %%
from Funciones.Tarea_5 import analisis_binario
analisis_binario(Ximage,yimage,caracteres)
# Out:
# Exactitud:0.9923611111111111de los valores(0,1
# Sensibilidad:0.9944444444444445de los valores(0,1
# Precision:0.9903181189488244de los valores(0,1
# Exactitud:0.9854166666666667de los valores(0,2
# Sensibilidad:0.9847222222222223de los valores(0,2
# Precision:0.9860917941585535de los valores(0,2
# Exactitud:0.9895833333333334de los valores(0,3
# Sensibilidad:0.9944444444444445de los valores(0,3
# Precision:0.984869325997249de los valores(0,3
# Exactitud:0.9888888888888889de los valores(0,4
# Sensibilidad:0.9944444444444445de los valores(0,4
# Precision:0.9835164835164835de los valores(0,4
# Exactitud:0.9791666666666666de los valores(0,5
# Sensibilidad:0.9819444444444444de los valores(0,5
# Precision:0.9765193370165746de los valores(0,5
# Exactitud:0.9944444444444445de los valores(0,6
# Sensibilidad:0.9930555555555556de los valores(0,6
# Precision:0.9958217270194986de los valores(0,6
# Exactitud:0.9958333333333333de los valores(0,7
# Sensibilidad:0.9958333333333333de los valores(0,7
# ...
